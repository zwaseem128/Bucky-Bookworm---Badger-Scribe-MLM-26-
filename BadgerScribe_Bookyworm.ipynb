# %% [markdown]
# pip install jupyter-collaboration

# %%
# This is our official file for Bucky Bookroom 
#Collaborators: Chloe OH, Lokesh Sai Dasari, Lauren Pratt, Zain Waseem

# %%
pwd
# Out:
# 'C:\\Users\\zwaseem'

# %%
git remote add origin https://github.com/zwaseem128/Bucky-Bookworm---Badger-Scribe-MLM-26-/upload/Zains-Notebook
# Out:
#   Cell In[3], line 1
#     git remote add origin https://github.com/zwaseem128/Bucky-Bookworm---Badger-Scribe-MLM-26-/upload/Zains-Notebook
#         ^
# SyntaxError: invalid syntax
